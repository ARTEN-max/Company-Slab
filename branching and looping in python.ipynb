# %%
number=int(input("enter number"))
if number%2==0:
  print(f"the number {number} is an even number")
else:
  print(f"the number {number} is an odd number")

# %%
the_Musketeers=("Athos","Porthos","Aramis")
print(type(the_Musketeers))
candidate="dd"
if candidate in the_Musketeers:
  print(f"{candidate} is a musketeer")
else:
  print(f"{candidate} is not a musketeer")
# Out:
# <class 'tuple'>
# dd is not a musketeer

# %%
day=input("enter day")
if day=="Sunday":
  print("today is the day of the sun.")
elif day=="Monday":
  print("today is the day of the moon.")
elif day=="Tuesday":
  print("Today is the day of Tyr, the god of war.")
else:
  print("invalid(input sunday,monday or tuesday)")
# Out:
# enter dayss
# invalid(input sunday,monday or tuesday)

# %%
number=15
if number%2==0:
  print(f"{number} is divisible by 2")
elif number%3==0:
  print(f"{number} is divisible by 3")
elif number%5==0:
  print(f"{number} is divisible by 3")
elif number%7==0:
  print(f"{number} is divisible by 3")
# Out:
# 15 is divisible by 3

# %%
number=12
if number%3 and number%5==0:
  print(f"{number} is divisible by 3 and 5")
elif not number%5==0:
  print(f"{number} is not divisible by 5")
# Out:
# 12 is not divisible by 5

# %%
if {"a":34}:
  print(True)
else:
  print(False)
# Out:
# True

# %%
if None:
  print(True)
else:
  print(False)
# Out:
# False

# %%
number=10
if number%2==0:
  print("even")
  if number%3==0:
    print("div by 3")
  else:
    print("not div by 3")
else:
  print("odd")
  if number%5==0:
    print("div by 5")
  else:
    print("not div by 5")

# %%
num=13
if num%2==0:
  parity="even"
else:
  parity="odd"
print(f"the number {num} is {parity}")
# Out:
# the number 13 is odd

# %%
num=13
parity="even" if num%2==0 else "odd"
print(f"the number {num} is {parity}")
# Out:
# the number 13 is odd

# %%
import time
startTime=time.time()
result=1
i=1
while i<=1000:
  result=result*i
  i=i+1
print(result)
endTime=time.time()
print("time taken=",endTime-startTime)
# Out:
# ...
# time taken= 0.0029337406158447266

# %%
i=1
result=1
while i<=100:
  result*=i
  if i==42:
    print("magic number 42 reached")
    break
  i=i+1
print(i)
print(result)
# Out:
# magic number 42 reached
# 42
# 1405006117752879898543142606244511569936384000000000

# %%
days=["Monday","Tueday","Wednesday"]
for day in days:
  print(day)
# Out:
# Monday
# Tueday
# Wednesday

# %%
for char in "Abdul Rahman":
  print(char)
# Out:
# A
# b
# d
# u
# l
#
# R
# a
# h
# m
# a
# n

# %%
for fruit in ("A","B","G"):
  print(fruit)
# Out:
# A
# B
# G

# %%
person={
    "name":"John Doe",
    "age":"32",
    "sex":"male"
}
for key in person:
  print(key,person[key])
# Out:
# name John Doe
# age 32
# sex male

# %%
for value in person.values():
  print(value)
